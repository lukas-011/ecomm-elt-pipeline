# %% [markdown]
# Imports

# %%
import sys
import os

extract_path = r"C:\Users\Lukanator\Documents\VisualStudioCodeProjects\ecomm-etl-pipeline\01-Extract"
sys.path.insert(0, extract_path)

# Verify the path was added and check for extract.py
print(f"Added path: {sys.path[0]}")
print(f"Files in directory: {os.listdir(extract_path)}")

from extract import run
# Out:
# Added path: C:\Users\Lukanator\Documents\VisualStudioCodeProjects\ecomm-etl-pipeline\01-Extract
# Files in directory: ['extract.py', '__pycache__']

# %%
os.chdir(os.path.abspath(os.path.join(extract_path, os.pardir)))

raw = run()
train = raw["train"]
test = raw["test"]
train = raw["train"]
test = raw["test"]
# Out:
# ==================================================
#   EXTRACT — TRAIN split
# ==================================================
#
# >> Loading files...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 raw = run()
#       2 train = raw["train"]
#       3 test = raw["test"]
#
# File c:\Users/Lukanator/Documents/VisualStudioCodeProjects/ecomm-etl-pipeline/01-Extract\extract.py:141, in run()
#     135 def run() -> dict[str, dict[str, pd.DataFrame]]:
#     136     """
#     137     Entry point called by main.py.
#     138     Returns: { 'train': {table: df, ...}, 'test': {table: df, ...} }
#     139     """
#     140     return {
# --> 141         "train": extract_split("train"),
#     142         "test":  extract_split("test"),
#     143     }
#
# File c:\Users/Lukanator/Documents/VisualStudioCodeProjects/ecomm-etl-pipeline/01-Extract\extract.py:123, in extract_split(split)
#     121 print("\n>> Loading files...")
#     122 for table in TABLES:
# --> 123     df = _load_csv(split, table)
#     124     _validate_columns(df, table, split)
#     125     result[table] = df
#
# File c:\Users/Lukanator/Documents/VisualStudioCodeProjects/ecomm-etl-pipeline/01-Extract\extract.py:68, in _load_csv(split, table)
#      65 filepath = os.path.join(DATA_DIR, split, filename)
#      67 if not os.path.exists(filepath):
# ---> 68     raise FileNotFoundError(f"Expected file not found: {filepath}")
#      70 df = pd.read_csv(filepath)
#      71 print(f"  [OK] {filename} — {len(df):,} rows loaded")
#
# FileNotFoundError: Expected file not found: 00-Test-Data\Ecommerce Order Dataset\train\df_Customers.csv
